# %% [markdown]
# # Tarea 05: iteraciones en Python
#
# Completa los tres ejercicios usando `while`, `for`, `break`, `continue`, contadores, acumuladores, `try/except`, `None`, máximo y mínimo.
#
# No uses funciones definidas por ti, módulos ni bibliotecas externas.
#
# Reemplaza cada comentario `TODO`, ejecuta todas las celdas y conserva los resultados.
#
# Entrega el archivo como `05-tarea-iteraciones-apellido-nombre.ipynb`.

# %% [markdown]
# ## Ejemplo: variable de control
#
# Ejecuta la celda y cambia el valor inicial de `n`.

# %%
n = 5
while n > 0:
    print(n)
    n = n - 1
print('Despegue!')

# %% [markdown]
# ## Ejercicio 1: total, cantidad y promedio
#
# Completa el programa. Debe procesar los datos de `entradas` hasta encontrar `done`.
#
# Requisitos:
#
# - usar `while` y `break`;
# - convertir los datos válidos con `int`;
# - mostrar `Entrada invalida` para datos no numéricos;
# - usar un contador y un acumulador;
# - mostrar total, cantidad y promedio;
# - evitar la división entre cero.
#
# Resultado esperado: total `16`, cantidad `3`, promedio `5.333333333333333`.

# %%
# Ejercicio 1: completa los TODO y ejecuta la celda.
entradas = ['4', '5', 'bad data', '7', 'done']
posicion = 0
total = 0
contador = 0

while True:
    entrada = entradas[posicion]
    posicion = posicion + 1
    if entrada == 'done':
        break
    try:
        numero = int(entrada)
    except ValueError:
        print('Entrada invalida')
        continue
    # TODO: acumula el numero en total.
    # TODO: aumenta contador en uno.

# TODO: muestra total, cantidad y promedio.
if contador > 0:
    print('Total:', total)
    print('Cantidad:', contador)
    print('Promedio:', total / contador)
else:
    print('No se ingresaron numeros')

# %% [markdown]
# ## Ejercicio 2: recorrer datos con `for`
#
# Completa el programa para contar y sumar los valores mayores o iguales a 10 de `[12, 7, 25, 4, 18, 9]`.
#
# Requisitos:
#
# - usar `for`;
# - usar `if`;
# - usar `continue` para ignorar valores menores que 10;
# - mostrar cantidad y suma.
#
# Resultado esperado: cantidad `3`, suma `55`.

# %%
# Ejercicio 2: completa los TODO y ejecuta la celda.
valores = [12, 7, 25, 4, 18, 9]
cantidad = 0
suma = 0

for valor in valores:
    if valor < 10:
        # TODO: ignora este valor y pasa a la siguiente iteracion.
        pass
    # TODO: aumenta cantidad.
    # TODO: suma valor en suma.

print('Cantidad de valores >= 10:', cantidad)
print('Suma de valores >= 10:', suma)

# %% [markdown]
# ## Ejercicio 3: mayor y menor
#
# Completa el programa para encontrar el mayor y el menor valor de `[12, 7, 25, 4, 18, 9]` sin usar `max()` ni `min()`.
#
# Requisitos:
#
# - inicializar `mayor` y `menor` con `None`;
# - recorrer la lista con `for`;
# - actualizar cada valor mediante condiciones;
# - mostrar el mayor y el menor después del bucle.
#
# Resultado esperado: mayor `25`, menor `4`.

# %%
# Ejercicio 3: completa los TODO y ejecuta la celda.
valores = [12, 7, 25, 4, 18, 9]
mayor = None
menor = None

for valor in valores:
    # TODO: si mayor es None o valor es mayor que mayor, actualiza mayor.
    # TODO: si menor es None o valor es menor que menor, actualiza menor.
    print('Valor:', valor, 'Mayor:', mayor, 'Menor:', menor)

print('Mayor final:', mayor)
print('Menor final:', menor)

# %% [markdown]
# ## Entrega
#
# Ejecuta todas las celdas y verifica estos resultados:
#
# - Ejercicio 1: total `16`, cantidad `3`, promedio `5.333333333333333`.
# - Ejercicio 2: cantidad `3`, suma `55`.
# - Ejercicio 3: mayor `25`, menor `4`.
#
# Lista de verificación:
#
# - [ ] Todos los comentarios `TODO` fueron completados.
# - [ ] El programa usa `while`, `for`, `break` y `continue`.
# - [ ] Se ejecutan correctamente los datos inválidos.
# - [ ] Todas las salidas coinciden con los resultados esperados.
# - [ ] El notebook se ejecuta completo desde un kernel reiniciado.
