# %% [markdown]
# # Tarea: Decisiones y funciones en Python
# ### Programación en Python — Posgrado
#
# ## Propósito
#
# Esta tarea integra los temas trabajados en: variables, entrada y conversión de datos, operadores de comparación, estructuras `if/elif/else`, funciones, parámetros y `return`.
#
# El contexto es un pequeño análisis de indicadores laborales. La solución debe construirse con conceptos vistos en clase.
#
# ## Instrucciones
#
# - Trabaje directamente en este cuaderno y complete las celdas marcadas con `# TODO`.
# - Use variables, listas simples, ciclos `for`, condicionales y funciones.
# - Las funciones deben calcular y devolver resultados con `return`. Use `print` solo para mostrar resultados.
# - Las funciones deben incluir una explicación breve en un comentario o en Markdown.
# - El cuaderno debe ejecutarse completo y en orden sin errores.
#
# ## Partes de la tarea
#
# 1. Clasificación de una persona según edad e ingreso.
# 2. Cálculo de pago con horas extra.
# 3. Clasificación de calificaciones.
# 4. Análisis de varias personas usando listas y funciones.
# 5. Reflexión final sobre el diseño de la solución.

# %% [markdown]
# ## Parte 1. Clasificación socioeconómica
#
# Escriba una función llamada `clasificar_persona(edad, ingreso)` que devuelva una categoría según estas reglas:
#
# - Si `edad` es menor que 18: `'Menor de edad'`.
# - Si `edad` es 18 o más y `ingreso` es menor que 1000000: `'Adulto con ingreso bajo'`.
# - Si `edad` es 18 o más y `ingreso` está entre 1000000 y 3000000: `'Adulto con ingreso medio'`.
# - Si `edad` es 18 o más y `ingreso` es mayor que 3000000: `'Adulto con ingreso alto'`.
#
# Use `if`, `elif` y `else`. La función no debe imprimir; debe devolver una cadena.

# %%
def clasificar_persona(edad, ingreso):
    # TODO: escriba la función usando if, elif y else
    pass

print(clasificar_persona(17, 500000))
print(clasificar_persona(30, 800000))
print(clasificar_persona(30, 2000000))
print(clasificar_persona(30, 4000000))

# %% [markdown]
# ## Parte 2. Pago con horas extra
#
# Escriba `computepay(hours, rate)`. Las primeras 40 horas se pagan a tarifa normal; las horas adicionales se pagan a tiempo y medio.
#
# La función debe devolver el pago total. Luego pruébela con 45 horas y tarifa 10. El resultado esperado es `475.0`.
#
# Después, cambie los valores de las variables y observe cómo se comporta la función con 40 horas y con menos de 40 horas.

# %%
def computepay(hours, rate):
    # TODO: use if/else y return
    pass

hours = 45
rate = 10
print('Hours:', hours)
print('Rate:', rate)
print('Pay:', computepay(hours, rate))

# %% [markdown]
# ## Parte 3. Clasificación de calificaciones
#
# Escriba `computegrade(score)` para convertir un puntaje entre 0.0 y 1.0 en una calificación:
#
# - `score >= 0.9`: `'A'`
# - `score >= 0.8`: `'B'`
# - `score >= 0.7`: `'C'`
# - `score >= 0.6`: `'D'`
# - En los demás casos: `'F'`
#
# La función debe devolver la letra. Para esta tarea puede asumir que el valor ingresado está entre 0.0 y 1.0. Pruebe la función con `0.95`, `0.75` y `0.5`.

# %%
def computegrade(score):
    # TODO: use if, elif, else y return
    pass

print(computegrade(0.95))
print(computegrade(0.75))
print(computegrade(0.5))

# %% [markdown]
# ## Parte 4. Entrada por teclado
#
# Adapte el programa para que solicite al usuario una edad, un ingreso y un puntaje usando `input()`. Convierta edad e ingreso a números enteros y el puntaje a `float`.
#
# Luego llame a las funciones correspondientes e imprima los resultados. Esta versión puede ejecutarse después de las pruebas anteriores; no es necesario usar manejo de excepciones.

# %%
# Versión opcional con entrada por teclado
edad_usuario = int(input('Edad: '))
ingreso_usuario = int(input('Ingreso mensual: '))
puntaje_usuario = float(input('Puntaje entre 0.0 y 1.0: '))

print(clasificar_persona(edad_usuario, ingreso_usuario))
print(computegrade(puntaje_usuario))
